# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict

# %%
model = ChatGoogleGenerativeAI(model='gemini-3.6-flash')

# %%
class BlogState(TypedDict):
    
    title: str
    outline: str
    content: str

# %%
def create_outline(state: BlogState) -> BlogState:
    
    title = state['title']
    
    prompt = f'Generate a detailed outline for a blog on the topic - {title} '
    
    outline = model.invoke(prompt).content
    
    state['outline'] = outline
    
    return state

# %%
def create_blog(state: BlogState) -> BlogState:
    
    title = state['title']
    
    outline = state['outline']
    
    prompt = f"Write a detailed blog on the title  - {title} using the following outline \n {outline}"
    
    content = model.invoke(prompt).content
    
    state['content'] = content
    
    return state

# %%
graph = StateGraph(BlogState)

graph.add_node('create_outline', create_outline)
graph.add_node('create_blog', create_blog)

graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline', 'create_blog')
graph.add_edge('create_blog', END)

workflow = graph.compile()

# %%
initial_state = {'title':"Rise of AI in India"}

final_state = workflow.invoke(initial_state)

print(final_state['content'])
# Out:
# Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.
# [{'type': 'text', 'text': '# The Rise of AI in India: From IT Hub to Global AI Powerhouse\n\nIn a quiet village in rural Maharashtra, a soybean farmer notices a unusual yellowing pattern spread across his crop. A decade ago, this would have meant waiting days for a government agricultural officer to visit, or risking his entire yield to local guesswork. Today, he pulls out a budget smartphone, opens a local chat application, takes a photograph of the leaf, and speaks a question in his native Marathi. \n\nWithin seconds, an AI-powered agent analyzes the image, identifies a early-stage fungal infection, and delivers a voice response recommending an affordable, locally available treatment. \n\nThis is not a futuristic demo from Silicon Valley; it is everyday reality across India today.\n\n```\n       ┌─────────────────────────────────────────────────────────┐\n       │                   THE INDIA AI ENGINE                   │\n       └────────────────────────────┬────────────────────────────┘\n                                    │\n       ┌────────────────────────────┼────────────────────────────┐\n       ▼                            ▼                            ▼\n┌───────────────┐           ┌───────────────┐           ┌───────────────┐\n│ DIGITAL INFRA │           │  TALENT POOL  │           │ DEEPTECH VCs  │\n│ India Stack & │           │ 1.5M+ Annual  │           │ Shift Towards │\n│  Cheap Data   │           │ STEM Grads    │           │ GenAI/DeepTech│\n└───────┬───────┘           └───────┬───────┘           └───────┬───────┘\n        │                           │                           │\n        └───────────────────────────┼───────────────────────────┘\n                                    │\n                                    ▼\n       ┌─────────────────────────────────────────────────────────┐\n       │               NATIONAL AI IMPACT AT SCALE               │\n       │    Agriculture • Healthcare • FinTech • Governance      │\n       └─────────────────────────────────────────────────────────┘\n```\n\nFor decades, India was celebrated primarily as the "back office of the world"—the undisputed leader in IT services, software maintenance, and business process outsourcing. Today, a fundamental architectural shift is underway. India is transitioning rapidly from an IT service distributor into a global **DeepTech** innovator and generative AI powerhouse. \n\nWith a massive digital dataset, a world-class public tech infrastructure, a thriving startup ecosystem, and proactive state policy, India is forging a distinct blueprint for Artificial Intelligence: one focused not just on commercial efficiency, but on solving massive, real-world socio-economic challenges. \n\nWhat is driving this unprecedented **GenAI India** boom? Which industries are being fundamentally disrupted? And what structural hurdles must the nation cross to secure its spot at the global AI table?\n\n---\n\n## II. The Catalyst: Why India’s AI Engine is Firing Now\n\nIndia’s rapid emergence in the AI landscape is not accidental; it is the convergence of structural digital readiness, demography, and capital reallocation.\n\n```\n+-------------------------------------------------------------------+\n|                        THE TRIAD OF GROWTH                        |\n+------------------------------------+------------------------------+\n| 1. DATA & DIGITAL INFRASTRUCTURE   | • World\'s cheapest mobile data\n|                                    | • India Stack (UPI, Aadhaar) |\n+------------------------------------+------------------------------+\n| 2. HUMAN CAPITAL & UPSKILLING      | • 1.5M+ annual STEM grads    |\n|                                    | • Mass pivot to ML/AI/LLMs   |\n+------------------------------------+------------------------------+\n| 3. CAPITAL & STARTUP ECOSYSTEM     | • Rise of Indic LLM builders |\n|                                    | • Surge in DeepTech VC funding\n+------------------------------------+-------------------------- ...

# %%
print(final_state['outline'])
# Out:
# [{'type': 'text', 'text': 'Here is a comprehensive, SEO-friendly, and detailed blog outline on the topic **"The Rise of AI in India: From IT Hub to Global AI Powerhouse."**\n\n---\n\n# Blog Title Ideas\n1. *The Rise of AI in India: From IT Hub to Global AI Powerhouse*\n2. *How India is Harnessing Artificial Intelligence to Drive the Next Tech Revolution*\n3. *AI in India: Current Landscape, Sectoral Impact, and the Road Ahead*\n4. *Silicon Valley of the East? Decoding India’s AI Boom*\n\n---\n\n## **I. Introduction**\n*   **The Hook:** Start with a compelling stat or visual image (e.g., How AI is enabling a farmer in rural Maharashtra to diagnose crop diseases using a smartphone in his native language).\n*   **Context:** Brief transition of India from a traditional IT services/outsourcing hub to a global product and deep-tech innovator.\n*   **Thesis Statement:** India is uniquely positioned to lead the global AI wave due to its massive data ecosystem, booming startup culture, proactive government policies, and unmatched talent pool.\n*   **Key Question to Answer:** What is driving this AI surge, which industries are being transformed, and what challenges lie ahead?\n\n---\n\n## **II. The Catalyst: Why India’s AI Engine is Firing Now**\n*   **1. The Digital Infrastructure Boom (The "Data Factor"):**\n    *   Impact of affordable high-speed internet and smartphone penetration.\n    *   The "India Stack" (UPI, Aadhaar, DigiLocker) creating massive datasets for AI models.\n*   **2. A Massive Talent Pool:**\n    *   India produces millions of STEM graduates annually.\n    *   Transition of software engineers upskilling into Machine Learning (ML), Deep Learning, and Generative AI.\n*   **3. Thriving Startup Ecosystem:**\n    *   Emergence of AI-first unicorns and startups (e.g., Krutrim, Sarvam AI, Yellow.ai, Fractal).\n    *   Venture Capital (VC) confidence shift toward DeepTech investments.\n\n---\n\n## **III. Sectoral Impact: How AI is Transforming Bharat**\n\n*   **1. Agriculture (Agritech):**\n    *   Precision farming, yield prediction, and pest control using AI-driven drone imagery.\n    *   *Example:* AI chatbots assisting farmers with weather updates and market prices in local dialects.\n*   **2. Healthcare:**\n    *   Bridging the urban-rural doctor ratio gap.\n    *   AI-powered diagnostics (e.g., early detection of tuberculosis, diabetic retinopathy, and cancer through medical imaging).\n*   **3. Financial Services (FinTech & Banking):**\n    *   AI for credit scoring for the unbanked population.\n    *   Fraud detection, automated customer service, and voice-assisted banking in vernacular languages.\n*   **4. Education & Governance:**\n    *   Hyper-personalized learning experiences in EdTech.\n    *   Government services delivery: AI-driven governance for welfare distribution and traffic management.\n\n---\n\n## **IV. The "Hyper-Local" Advantage: AI for Vernacular India**\n*   **The Multi-Lingual Challenge:** India\'s linguistic diversity (22 official languages, thousands of dialects).\n*   **Project Bhashini:** The government’s open-source AI platform breaking language barriers.\n*   **Indic LLMs (Large Language Models):** The rise of indigenous AI models built specifically for Indian languages and cultural contexts (e.g., Sarvam\'s OpenHathi, Ola’s Krutrim).\n\n---\n\n## **V. Government Policies & National Initiatives**\n*   **"AI for All" Strategy (NITI Aayog):** India’s national strategy positioning AI as a tool for social inclusion.\n*   **IndiaAI Mission:** The government’s ₹10,000+ Crore ($1.2 Billion) budget approval to build public AI compute infrastructure (GPUs), foster startups, and democratize access.\n*   **Global Leadership:** India’s role as the Chair of the Global Partnership on AI (GPAI).\n\n---\n\n## **VI. Key Challenges and Roadblocks**\n*   **1. Infrastructure Deficit:** High cost and shortage of high-performance computing power (GPUs).\n*   **2. The Skill Gap:** Quantity vs. Quality—the need for ...
