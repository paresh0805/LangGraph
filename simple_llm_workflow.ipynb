# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict

# %%
model = ChatGoogleGenerativeAI(model='gemini-3.6-flash')

# %%
class LLMState(TypedDict):
    
    question: str
    answer: str

# %%
def llm_qa(state: LLMState) -> LLMState:
    
    question = state['question']
    
    prompt = f'Answer the following question {question}'
    
    answer = model.invoke(prompt).content
    
    state['answer']=answer
    
    return state

# %%
graph = StateGraph(LLMState)

graph.add_node('llm_qa', llm_qa)

graph.add_edge(START, 'llm_qa')
graph.add_edge('llm_qa',END)

workflow = graph.compile()

# %%
initial_state = {'question': 'How far is moon from the Earth'}

final_state = workflow.invoke(initial_state)

print(final_state['answer'])
# Out:
# [{'type': 'text', 'text': 'On average, the Moon is about **384,400 kilometers (238,855 miles)** away from Earth.\n\nHowever, because the Moon travels in an oval-shaped (elliptical) orbit around Earth, the distance is constantly changing:\n\n* **Closest approach (Perigee):** About **363,300 km (225,623 miles)**\n* **Farthest point (Apogee):** About **405,500 km (251,966 miles)**\n\n### To put that distance into perspective:\n* **Fit the planets:** You could fit all the other seven planets in our solar system side-by-side in the space between Earth and the Moon.\n* **Fit Earths:** You could fit about **30 Earths** between us and the Moon.\n* **Travel time:** Light (or a radio signal) takes about **1.3 seconds** to travel from Earth to the Moon.', 'extras': {'signature': '...'}}]
